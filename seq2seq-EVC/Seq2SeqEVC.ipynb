# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/voiceconversion/seq2seq-EVC
# Out:
# /content/drive/MyDrive/voice conversion/seq2seq-EVC

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not find a version that satisfies the requirement torch==1.0.1 (from versions: 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0)
# ERROR: No matching distribution found for torch==1.0.1

# %%
# !python extract_features.py (please customize "path" and "kind", and edit the codes for "spec" or "mel-spec")
# !python /content/drive/MyDrive/voiceconversion/seq2seq-EVC/pre-train/reader/generate_list_mel.py
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `('
# /bin/bash: -c: line 1: `python extract_features.py (please customize "path" and "kind", and edit the codes for "spec" or "mel-spec")'
# preparing evaluation list...
# Error processing file /content/drive/MyDrive/voiceconversion/seq2seq-EVC/0013/mel/p225/p225_212.txt: could not convert string 'After' to float64 at row 0, column 1.
# File not found: /content/drive/MyDrive/voiceconversion/seq2seq-EVC/0013/txt/p225/p225_212.txt
# Error processing file /content/drive/MyDrive/voiceconversion/seq2seq-EVC/0013/mel/p225/p225_335.txt: could not convert string 'We' to float64 at row 0, column 1.
# File not found: /content/drive/MyDrive/voiceconversion/seq2seq-EVC/0013/txt/p225/p225_335.txt
# Error processing file /content/drive/MyDrive/voiceconversion/seq2seq-EVC/0013/mel/p225/p225_030.txt: could not convert string 'People' to float64 at row 0, column 1.
# ...

# %%
# !python /content/drive/MyDrive/voiceconversion/seq2seq-EVC/pre-train/train.py -l logdir \
-o outdir --n_gpus=1 --hparams=speaker_adversial_loss_w=20.,ce_loss=False,speaker_classifier_loss_w=0.1,contrastive_loss_w=30.
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/voiceconversion/seq2seq-EVC/pre-train/train.py", line 15, in <module>
#     from reader import TextMelIDLoader, TextMelIDCollate, id2sp
#   File "/content/drive/MyDrive/voiceconversion/seq2seq-EVC/pre-train/reader/__init__.py", line 1, in <module>
#     from .reader import TextMelIDLoader, TextMelIDCollate
#   File "/content/drive/MyDrive/voiceconversion/seq2seq-EVC/pre-train/reader/reader.py", line 5, in <module>
#     from .symbols import ph2id
#   File "/content/drive/MyDrive/voiceconversion/seq2seq-EVC/pre-train/reader/symbols.py", line 5, in <module>
#     for seen_speaker in os.listdir('/data07/zhoukun/VCTK-Corpus/spec'):
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/data07/zhoukun/VCTK-Corpus/spec'

# %%
# !python extract.py (please customize "path" and "kind", and edit the codes for "spec" or "mel-spec")
# !python /content/drive/MyDrive/voiceconversion/seq2seq-EVC/pre-train/reader/generate_list_mel.py
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `('
# /bin/bash: -c: line 1: `python extract.py (please customize "path" and "kind", and edit the codes for "spec" or "mel-spec")'
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/voiceconversion/seq2seq-EVC/pre-train/reader/generate_list_mel.py", line 34, in <module>
#     for seen_speaker in os.listdir('/data07/zhoukun/VCTK-Corpus/mel'):
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/data07/zhoukun/VCTK-Corpus/mel'

# %%
# !python /content/drive/MyDrive/voiceconversion/seq2seq-EVC/pre-train/train.py -l logdir \
-o outdir_emotion_IS --n_gpus=1 -c '/content/drive/MyDrive/voiceconversion/seq2seq-EVC/pre-train/outdir/checkpoint_234000 (The path to your Pre-trained models from Stage I)' --warm_start
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/voiceconversion/seq2seq-EVC/pre-train/train.py", line 15, in <module>
#     from reader import TextMelIDLoader, TextMelIDCollate, id2sp
#   File "/content/drive/MyDrive/voiceconversion/seq2seq-EVC/pre-train/reader/__init__.py", line 1, in <module>
#     from .reader import TextMelIDLoader, TextMelIDCollate
#   File "/content/drive/MyDrive/voiceconversion/seq2seq-EVC/pre-train/reader/reader.py", line 5, in <module>
#     from .symbols import ph2id
#   File "/content/drive/MyDrive/voiceconversion/seq2seq-EVC/pre-train/reader/symbols.py", line 5, in <module>
#     for seen_speaker in os.listdir('/data07/zhoukun/VCTK-Corpus/spec'):
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/data07/zhoukun/VCTK-Corpus/spec'

# %%
# !python /content/drive/MyDrive/voiceconversion/seq2seq-EVC/conversion/inference_embedding.py -c '/content/drive/MyDrive/voiceconversion/seq2seq-EVC/fine-tune/outdir_emotion_update/checkpoint_3200 [YOUR EMOTION TRAINING CHECKPOINT]' --hparams speaker_A='Neutral',speaker_B='Happy',speaker_C='Sad',speaker_D='Angry',training_list='/home/zhoukun/nonparaSeq2seqVC_code-master/fine-tune/reader/emotion_list/testing_mel_list.txt',SC_kernel_size=1
# Out:
# 2025-01-22 15:29:40.872586: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-22 15:29:40.892925: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-22 15:29:40.899765: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-22 15:29:40.916264: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python /content/drive/MyDrive/voiceconversion/seq2seq-EVC/conversion/inference_A.py -c '/content/drive/MyDrive/voiceconversion/seq2seq-EVC/pre-train/outdir_emotion_update/checkpoint_3200[YOUR EMOTION TRAINING CHECKPOINT]' --num 20 --hparams validation_list='/home/zhoukun/nonparaSeq2seqVC_code-master/fine-tune/reader/emotion_list/evaluation_mel_list.txt',SC_kernel_size=1
# Out:
# 2025-01-22 15:32:46.093046: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-22 15:32:46.113225: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-22 15:32:46.119594: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-22 15:32:46.134605: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
